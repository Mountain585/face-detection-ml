# %% [markdown]
# <a href="https://colab.research.google.com/github/Mountain585/face-detection-ml/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🚀 Real vs Fake Face Detector (Live Demo)
# This notebook demonstrates the classical ML pipeline.

print("✅ Installing required libraries...")
# !pip install opencv-python numpy scikit-learn scikit-image matplotlib seaborn -q

print("✅ Cloning the GitHub repository...")
# !git clone https://github.com/Mountain585/face-detection-ml.git

print("✅ Setup complete! The code is ready in the 'face-detection-ml' folder.")
print("👉 Click the folder icon on the left to explore the files, or run the main.py script below.")
# Out:
# ✅ Installing required libraries...
# ✅ Cloning the GitHub repository...
# Cloning into 'face-detection-ml'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# ✅ Setup complete! The code is ready in the 'face-detection-ml' folder.
# 👉 Click the folder icon on the left to explore the files, or run the main.py script below.
